# %% [markdown]
# #### __패키지란 무엇인가?__

# %% [raw]
# 패키지(Packages)는 도트(.)를 사용하여 파이썬 모듈을 계층적(디렉터리 구조)으로 관리할 수 있게 해준다.
# 모듈 이름이 A,B인 경우에 A는 패키지 이름 / B는 A패키지의 B모듈이 된다.

# %% [markdown]
# ##### __패키지 만들기__

# %% [markdown]
# ##### 패키지 기본 구성 요소 준비하기

# %% [markdown]
# ######

# %% [markdown]
# #### __init__.py 의 용도

# %% [raw]
# __init__.py 파일은 해당 디렉터리가 패키지의 일부임을 알려주는 역할을 한다.
# 만약, game,sound,graphic등 패키지에 포함된 디렉터리에 __init__.py 파일이 없다면 패키지로 인식되지 않는다.

# %% [markdown]
# ######

# %% [markdown]
# #### __relative패키지__

# %% [raw]
# 만약 graphic 디렉터리의 render.py모듈일 sound 디렉터리의 echo.py 모듈을 사용하고 싶다면 어떻게 해야 할까?
# 다음과 같이 render.py를 수정하면 가능하다.
