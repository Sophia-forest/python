# %% [markdown]
# #### __오류는 어떨 때 발생하는가?__

# %%
f = open("나없는파일",'r')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-c262055d665b> in <module>
# ----> 1 f = open("나없는파일",'r')
#
# FileNotFoundError: [Errno 2] No such file or directory: '나없는파일'

# %%
4/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-2-221068dc2815> in <module>
# ----> 1 4/0
#
# ZeroDivisionError: division by zero

# %%
a = [1,2,3]
a[4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-59fd82b1af02> in <module>
#       1 a = [1,2,3]
# ----> 2 a[4]
#
# IndexError: list index out of range

# %% [markdown]
# ######

# %% [markdown]
# #### __오류 예외 처리 기법__

# %% [markdown]
# ##### __try, except문__

# %% [raw]
# 1. try, except 만 쓰는 기법
# try:
#     ...
# excetp:
#     ...

# %% [raw]
# 2. 발생 오류만 포함한 except문
# try:
#     ...
# except 발생 오류:
#     ...

# %% [raw]
# 3. 발생 오류와 오류 메시지 변수까지 포함한 except문
# try:
#     ...
# except 발생 오류 as 오류 메시지 변수:
#     ...

# %%
try:
    4/0
except ZeroDivisionError as e:
    print(e)
# Out:
# division by zero

# %% [markdown]
# ######

# %% [markdown]
# ##### __try ...finally__

# %%
f = open('foo.txt', "w")
try:
    # 무언가를 수행한다.
finally:
    f.close()
# foo.txt파일을 쓰기 모드로 연 후에 try문을 수행한 후 예외 발생 여부와 
# 상관없이 finally절에서 f.close()로 열린 파일을 닫을 수 있다.
# Out:
#   File "<ipython-input-19-baf9b24aed60>", line 4
#     finally:
#     ^
# IndentationError: expected an indented block

# %% [markdown]
# ######

# %% [markdown]
# ##### __여러 개의 오류 처리하기__

# %%
try:
    a=[1,2]
    print(a[3])
    4/0
except ZeroDivisionError:
    print("0으로 나눌 수 없습니다.")
except IndexError:
    print("인덱싱 할 수 없습니다.")
# Out:
# 인덱싱 할 수 없습니다.

# %%
try:
    a=[1,2]
    print(a[3])
    4/0
except ZeroDivisionError as e:
    print(e)
except IndexError as e:
    print(e)
# Out:
# list index out of range

# %%
try:
    4/0
except (ZeroDivisionError, IndexError) as e:
    print(e)
# Out:
# division by zero

# %% [markdown]
# ######

# %% [markdown]
# #### __오류 회피하기__

# %%
try: 
    f = open("나없는파일",'r')
except FileNotFoundError:    # 파일이 없더라도 오류를 발생시키지 않고 통과한다.
    pass

# %% [markdown]
# ######

# %% [markdown]
# #### __오류 일부러 발생시키기__  : raise명령어 사용

# %%
class Bird:
    def fly(self):
        raise NotImplementedError

# %%
class Eagle(Bird):    # Eagle 클래스는 Bird클래스를 상속받음.
    pass
eagle = Eagle()
eagle.fly()    # Bird클래스의 fly함수가 호출됨. -> raise문에 의해 NotImplemented Error가 발생함.
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-38-62d740709aa0> in <module>
#       2     pass
#       3 eagle = Eagle()
# ----> 4 eagle.fly()    # Bird클래스의 fly함수가 호출됨.
#
# <ipython-input-36-e8d1e4453b08> in fly(self)
#       1 class Bird:
#       2     def fly(self):
# ----> 3         raise NotImplementedError
#
# NotImplementedError:

# %%
class Eagle(Bird):    # Eagle 클래스는 Birt 클래스 상속받음
    def fly(self):
        print("very fast")
        
eagle = Eagle()
eagle.fly()
# Out:
# very fast

# %% [markdown]
# ######

# %% [markdown]
# #### __예외 만들기__

# %% [raw]
# 특수한 경우에만 예외 처리를 하기 위해서 종종 예외를 만들어서 사용
# 예외는 파이썬 내장 클래스인 Exception클래스를 상속하여 만들 수 있다.

# %%
class MyError(Exception):
    pass

# %%
def say_nick(nick):
    if nick == '바보':
        raise MyError()
    print(nick)

# %%
say_nick("천사")
# Out:
# 천사

# %%
say_nick("바보")
# Out:
# ---------------------------------------------------------------------------
# MyError                                   Traceback (most recent call last)
# <ipython-input-5-e2fcd6d5b76b> in <module>
# ----> 1 say_nick("바보")
#
# <ipython-input-3-3c5d9303005c> in say_nick(nick)
#       1 def say_nick(nick):
#       2     if nick == '바보':
# ----> 3         raise MyError()
#       4     print(nick)
#
# MyError:

# %% [raw]
# 예외 처리 기법을 사용하여 MyError 발생을 예외 처리해 보자.

# %%
try:
    say_nick("천사")
    say_nick("바보")
except MyError:
    print("허용되지 않는 별명입니다.")
# Out:
# 천사
# 허용되지 않는 별명입니다.

# %%
try:
    say_nick("천사")
    say_nick("바보")
except MyError as e:
    print(e)
# Out:
# 천사

# %% [markdown]
# ######

# %% [raw]
# 오류 메시지 보이게 하려면 ?

# %%
class MyError(Exception):
    def __str__(self):
        return "허용되지 않는 별명입니다."

# %%
try:
    say_nick("천사")
    say_nick("바보")
except MyError as e:
    print(e)
# Out:
# 천사
# 허용되지 않는 별명입니다.
