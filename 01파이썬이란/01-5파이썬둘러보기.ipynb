# %%
1+1
# Out:
# 2

# %% [markdown]
# #### __인터프리터 : 인터프리터란 사용자가 입력한 소스 코드를 실행하는 환경__
# #### __대화형 : 입력과 출력이 번갈아 이어지는 것__

# %%
import sys
sys.exit()
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3445: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
1+2
# Out:
# 3

# %%
3/2.4
# Out:
# 1.25

# %%
3*9
# Out:
# 27

# %% [markdown]
# #### __변수에 숫자 대입하고 계산하기__

# %%
a = 1

# %%
b =2

# %%
a+b
# Out:
# 3

# %% [markdown]
# #### __변수에 문자 대입하고 출력하기__

# %%
a = "Python"
print(a)
# Out:
# Python

# %%
a = "Python"
a
# Out:
# 'Python'

# %% [markdown]
# ######

# %% [markdown]
# #### __조건문 if__

# %%
a = 3

# %%
if a > 1:
    print("a is greater than 1")
# Out:
# a is greater than 1

# %% [markdown]
# ######

# %% [markdown]
# #### __반복문 for__

# %%
for a in [1,2,3]:
    print(a)
# Out:
# 1
# 2
# 3

# %% [markdown]
# ######

# %% [markdown]
# #### __반복문 while__

# %%
i = 0
while i < 3 :
    i = i + 1
    print(i)
# Out:
# 1
# 2
# 3

# %% [markdown]
# ######

# %% [markdown]
# #### __함수__

# %%
def add(a,b):
    return a+b

# %%
add(3,4)
# Out:
# 7
