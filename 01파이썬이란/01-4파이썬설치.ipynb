# %% [markdown]
# ## __파이썬 설치하기__

# %% [markdown]
# #### __(www.python.org/downloads)__

# %% [markdown]
# #### __1. 윈도우에서 파이썬 설치__

# %% [markdown]
# #### 1. 파이썬 공식 홈페이지의 다운로드 페이지에서 윈도우용 파이썬 언어 패키지 다운로드.

# %% [markdown]
# #### 2. 파이썬이 어느 곳에서든지 실행될 수 있도록 __'Add Python 3.x to PATH'__ 옵션 반드시 선택

# %% [markdown]
# #### 3. 프로그램 메뉴  :  시작 - > 모든 프로그램 - > Python3.7
