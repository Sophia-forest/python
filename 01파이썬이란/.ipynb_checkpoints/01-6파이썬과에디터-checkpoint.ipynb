# %% [markdown]
# #### 파이썬 대화형 인터프리터는 간단한 예제를 풀 때는 편리하지만 여러 줄의 복잡한 소스 코드를 가진 프로그램을 만들 때는 불편하다.
# #### 또한 인터프리터를 종료하자마자 프로그램이 사라지기 때문에 다시 사용하지 못한다는 단점이 있다.
# #### 그래서 여러 번 사용하기 위한 프로그램을 만들 때는 에디터를 사용한다.
# #### 에디터란 소스 코드를 편집할 수 있는 프로그래밍 툴을 말한다.
# #### 에디터에는 여러 가지 종류가 있다.
# #### 그 중 파이썬을 설치할 때 기본으로 설치되는 파이썬 IDLE('아이들') 에디터 사용할 것.

# %% [markdown]
# ####

# %% [markdown]
# ## __IDLE__(integrated Development and Learning Environment)

# %% [markdown]
# #### 파이썬 프로그램 작성을 도와주는 통합 개발 환경이다.

# %% [markdown]
# #### 시작 > 모든 프로그램 > Python 3.7 > IDLE  > IDLE 셸(Shell)창이 나타남

# %% [markdown]
# ##### __IDLE 셸 창(Shell Window)__ : IDLE 에디터에서 실행한 프로그램의 결과가 표시되는 창으로서 파이썬 셸과 동일한 기능을 수행한다. IDLE을 실행하면 가장 먼저 나타나는 창

# %% [markdown]
# ##### __IDLE 에디터 창(Editor Window)__ : IDLE 에디터가 실행되는 창

# %% [markdown]
# ###

# %% [markdown]
# #### 주석

# %%
"""
Auther : Sophia Lee
Date : 2021-05-22
이 프로그램은 Hello World 를 출력하는 프로그램이다.
"""
# Out:
# '\nAuther : Sophia Lee\nDate : 2021-05-22\n이 프로그램은 Hello World 를 출력하는 프로그램이다.\n'

# %% [markdown]
# ##

# %% [markdown]
# #### __추천 에디터__

# %% [markdown]
# ### __비주얼 스튜디오 코드(Visual Studio Code)__

# %% [markdown]
# ##### (code.visualstudio.com)

# %% [markdown]
# #### - 파이썬 전용 에디터가 아니고 여러 가지 언어를 지원하는 에디터
# #### - 비주얼 스튜디오 코드를 설치한 후 파이썬 편집을 위해 가장 먼저 해야 할 일은 파이썬 Extension 을 설치하는 것
# #### - 파이썬 Extension은 비주얼 스튜디오 코드를 실행 한 후 Extension 메뉴를 사용하여 설치할 수 있다!

# %% [markdown]
# ###

# %% [markdown]
# ### __파이참__

# %% [markdown]
# #### - 파이썬에 어느 정도 익숙해졌다면 파이참(PyCharm)을 사용해 보기를 적극 추천

# %% [markdown]
# #### - 가장 유명한 파이썬 에디터 중 하나로서 코드를 작성할 때 자동 완성, 문법 체크 등 편리한 기능을 많이 제공

# %% [markdown]
# #### - ( www.jetbrains.com/pycharm/download )

# %% [markdown]
# #### - 파이참은 파이썬 전용 에디터로서 별도의 Extension이나 플러그 인을 따로 설치할 필요가 없다
