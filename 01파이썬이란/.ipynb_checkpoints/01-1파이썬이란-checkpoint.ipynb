# %% [markdown]
# ##### 1990년 암스테르담의 귀도 반 로섬(Guido Van Rossum)이 개발한 인터프리터 언어.

# %% [markdown]
# #

# %% [markdown]
# ##### 파이썬 : 고대 신화에 나오는 파르나소스 산의 동굴에 살던 큰 뱀
# ##### 아폴로 신이 뎅파이에서 파이썬을 퇴치했다는 이야기가 전해짐

# %% [markdown]
# #

# %% [markdown]
# ##### 구글에서 만든 소프트웨어의 50%이상이 파이썬으로 작성되었음.
# ##### 온라인 사진 공유 서비스 인스타그램(Instagram), 파일 동기화 서비스 드롭박스(Dropbox)
# ##### 파이썬 프로그램은 공동 작업과 유지 보수가 매우 쉽고 편하다.
