# %% [markdown]
# ### __리스트는 어떻게 만들고 사용할까?__

# %%
odd = [1,3,5,7,9]

# %%
a = []

# %%
b = [1,2,3]

# %%
c = ['Life','is','too','short']

# %%
d = [1,2,'Life','is']

# %%
e = [1,2,['Life', 'is']]

# %%
# 리스트 안에는 어떠한 자료형도 포함시킬 수 있다.

# %% [markdown]
# ######

# %% [markdown]
# ### __리스트의 인덱싱과 슬라이싱__

# %% [markdown]
# ##### __리스트의 인덱싱__

# %%
a = [1,2,3]

# %%
a
# Out:
# [1, 2, 3]

# %%
a[0]
# Out:
# 1

# %%
a[0]+a[2]
# Out:
# 4

# %%
a[-1]
# Out:
# 3

# %%
a=[1,2,3,['a','b','c']]

# %%
a[0]
# Out:
# 1

# %%
a[-1]
# Out:
# ['a', 'b', 'c']

# %%
a[3]
# Out:
# ['a', 'b', 'c']

# %%
a[-1][0]
# Out:
# 'a'

# %%
a[-1][1]
# Out:
# 'b'

# %%
a[-1][2]
# Out:
# 'c'

# %% [markdown]
# ######

# %% [markdown]
# ##### __리스트의 슬라이싱__

# %%
a = [1,2,3,4,5]

# %%
a[0:2]
# Out:
# [1, 2]

# %%
a="12345"

# %%
a[0:2]
# Out:
# '12'

# %%
a=[1,2,3,4,5]

# %%
b=a[:2]

# %%
c=a[2:]

# %%
b
# Out:
# [1, 2]

# %%
c
# Out:
# [3, 4, 5]

# %% [markdown]
# #####

# %% [markdown]
# ##### 중첩된 리스트에서 슬라이싱하기

# %%
a = [1,2,3,['a','b','c'],4,5]

# %%
a[2:5]
# Out:
# [3, ['a', 'b', 'c'], 4]

# %%
a[3][:2]
# Out:
# ['a', 'b']

# %% [markdown]
# #####

# %% [markdown]
# ##### 리스트 연산하기

# %% [markdown]
# ###### 1. 리스트 더하기(+)

# %%
a = [1,2,3]

# %%
b = [4,5,6]

# %%
a+b
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# ######

# %% [markdown]
# ###### 2.리스트 반복하기(*)

# %%
a = [1,2,3]

# %%
a*3
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]

# %% [markdown]
# ######

# %% [markdown]
# ###### 3. 리스트 길이 구하기

# %%
a = [1,2,3]

# %%
len(a)
# Out:
# 3

# %% [markdown]
# ######

# %%
a = [1,2,3]

# %%
a[2] + "hi"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-cbafcaae950e> in <module>
# ----> 1 a[2] + "hi"
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
str(a[2]) + "hi"
# Out:
# '3hi'

# %% [markdown]
# #####

# %% [markdown]
# #### __리스트의 수정과 삭제__

# %% [markdown]
# ##### __리스트에서 값 수정하기__

# %%
a = [1,2,3]

# %%
a[2] = 4

# %%
a
# Out:
# [1, 2, 4]

# %% [markdown]
# ##### __del함수 사용해 리스트 요소 삭제하기__

# %%
a = [1,2,3]

# %%
del a[1]

# %%
a
# Out:
# [1, 3]

# %%
a = [1,2,3,4,5]

# %%
del a[2:]

# %%
a
# Out:
# [1, 2]

# %% [markdown]
# #### __리스트 관련 함수__

# %% [markdown]
# ##### __리스트에 요소 추가(append)__

# %%
a = [1,2,3]

# %%
a.append(4)

# %%
a
# Out:
# [1, 2, 3, 4]

# %%
a.append([5,6])

# %%
a
# Out:
# [1, 2, 3, 4, [5, 6]]

# %% [markdown]
# ######

# %% [markdown]
# ##### __리스트 정렬(sort)__

# %%
a = [1,4,3,2]

# %%
a.sort()

# %%
a
# Out:
# [1, 2, 3, 4]

# %%
a = ['a','c','b']

# %%
a.sort()

# %%
a
# Out:
# ['a', 'b', 'c']

# %% [markdown]
# ######

# %% [markdown]
# ##### __리스트 뒤집기(reverse)__

# %%
a = ['a','c','b']

# %%
a.reverse()

# %%
a
# Out:
# ['b', 'c', 'a']

# %% [markdown]
# ######

# %% [markdown]
# ##### __위치 반환(index)__

# %%
a = [1,2,3]

# %%
a.index(3)
# Out:
# 2

# %%
a.index(1)
# Out:
# 0

# %%
a.index(0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-108-affdffa288f1> in <module>
# ----> 1 a.index(0)
#
# ValueError: 0 is not in list

# %% [markdown]
# ######

# %% [markdown]
# ##### __리스트에 요소 삽입(insert)__

# %%
a = [1,2,3]

# %%
a.insert(0,4)

# %%
a
# Out:
# [4, 1, 2, 3]

# %%
a.insert(3,5)

# %%
a
# Out:
# [4, 1, 2, 5, 3]

# %% [markdown]
# ######

# %% [markdown]
# ##### __리스트 요소 제거(remove)__

# %%
a = [1,2,3,1,2,3]

# %%
a.remove(3)

# %%
a
# Out:
# [1, 2, 1, 2, 3]

# %%
a.remove(3)

# %%
a
# Out:
# [1, 2, 1, 2]

# %% [markdown]
# ######

# %% [markdown]
# ##### __리스트 요소 끄집어내기(pop)__ 맨 마지막 요소를 돌려주고 그 요소는 삭제

# %%
a = [1,2,3]

# %%
a.pop()
# Out:
# 3

# %%
a
# Out:
# [1, 2]

# %%
a=[1,2,3]

# %%
a.pop(1)
# Out:
# 2

# %%
a
# Out:
# [1, 3]

# %% [markdown]
# ##### __리스트에 포함된 요소 x의 개수 세기(count)__

# %%
a = [1,2,3,1]

# %%
a.count(1)
# Out:
# 2

# %% [markdown]
# ######

# %% [markdown]
# ##### __리스트 확장(extend)__

# %%
a = [1,2,3]

# %%
a.extend([4,5])

# %%
a
# Out:
# [1, 2, 3, 4, 5]

# %%
b = [6,7]

# %%
a.extend(b)

# %%
a
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %% [markdown]
# ######
