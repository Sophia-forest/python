# %% [markdown]
# ### __불 자료형이란?__

# %% [markdown]
# ##### _불(bool)자료형이란 참(True)과 거짓(False)를 나타내는 자료형_

# %% [markdown]
# ##### _True : 참 / False : 거짓_

# %% [markdown]
# ######

# %%
a = True

# %%
b = False

# %% [markdown]
# ######

# %%
type(a)
# Out:
# bool

# %%
type(b)
# Out:
# bool

# %% [markdown]
# ######

# %%
1 == 1
# Out:
# True

# %% [markdown]
# ######

# %%
2 > 1
# Out:
# True

# %% [markdown]
# ######

# %%
2 < 1
# Out:
# False

# %% [markdown]
# ######

# %% [markdown]
# #### __자료형의 참과 거짓__

# %% [markdown]
# ###### _문자열    :      "python"    :     참_
# ###### _문자열    :       ""      :    거짓_
# ###### _리스트    :     [1,2,3]    :    참_
# ###### _리스트    :        []      :   거짓_
# ###### _튜플      :       ()       :   거짓_
# ###### _딕셔너리  :       {}       :   거짓_
# ###### _숫자형    :  0이 아닌 숫자  :  참_
# ###### _숫자형    :        0        :  거짓_
# ###### _: None : 거짓_

# %%
a = [1,2,3,4]

# %%
while a:
    a.pop()

# %%
a
# Out:
# []

# %% [markdown]
# ######

# %%
if []:
    print("참")
else:
    print("거짓")
# Out:
# 거짓

# %% [markdown]
# ######

# %%
if [1,2,3]:
    print("참")
else:
    print("거짓")
# Out:
# 참

# %%
# 만약 [1,2,3]이 참이면 "참"이라는 문자열을 출력하고 그렇지 않으면 "거짓"이라는 문자열을 출력하라.

# %% [markdown]
# ######

# %% [markdown]
# #### __불 연산__

# %%
bool('python')
# Out:
# True

# %%
bool('')
# Out:
# False

# %% [markdown]
# ######

# %%
bool([1,2,3])
# Out:
# True

# %%
bool([])
# Out:
# False

# %%
bool(0)
# Out:
# False

# %%
bool(3)
# Out:
# True

# %% [markdown]
# ######

# %%
a = [1,2,3,4]
while a:
    a.pop()

# %%
if []:
    print("참")
else:
    print("거짓")
# Out:
# 거짓

# %%
if [1,2,3]:
    print("참")
else:
    print("거짓")
# Out:
# 참

# %% [markdown]
# ###### __만약 [1,2,3]이 참이면 "참"이라는 문자열을 출력하고 그렇지 않으면 "거짓"이라는 문자열을 출력하라.__

# %% [markdown]
# ######

# %% [markdown]
# ### __불 연산__

# %%
bool('python')
# Out:
# True

# %%
bool('')
# Out:
# False

# %%
bool([1,2,3])
# Out:
# True

# %%
bool([])
# Out:
# False

# %%
bool(0)
# Out:
# False

# %%
bool(3)
# Out:
# True

# %% [markdown]
# ######

# %% [markdown]
# ######
