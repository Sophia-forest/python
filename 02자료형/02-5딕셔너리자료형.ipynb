# %% [markdown]
# ### __딕셔너리란?__

# %% [markdown]
# #### __연관 배열(Associative array)__ __해시(Hash)__

# %% [markdown]
# ######

# %% [markdown]
# ### __딕셔너리는 어떻게 만들까?__

# %%
dic = {'name':'pey', 'phone':'0119993323', 'birth':'1118'}

# %%
a = {1: 'hi'}
