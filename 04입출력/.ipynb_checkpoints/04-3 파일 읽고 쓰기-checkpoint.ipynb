# %% [markdown]
# #### __파일 생성하기__

# %%
f = open("새파일.txt", 'w')

# %%
f.close()

# %% [markdown]
# ##### 파일객체 = open(파일 이름, 파일 열기 모드)

# %%
# r : 읽기 모드 - 파일을 읽기만 할 때 사용
# w : 쓰기 모드 - 파일에 내용을 쓸 때 사용
# a : 추가 모드 - 파일의 마지막에 새로운 내용을 추가할 때 사용

# %% [markdown]
# ######

# %%
# 새파일.txt파일을 C:/doit 디렉터리에 생성하고 싶다면 다음과 같이 작성해야 한다.

# %%
f = open("C:/doit/새파일.txt", 'w')
f.close()    # 열려 있는 파일 객체를 닫아 주는 역할

# %%
f = open("C:/doit/복습.txt", 'w')
f.close()

# %% [markdown]
# ######

# %% [markdown]
# #### __파일을 쓰기 모드로 열어 출력값 적기__

# %%
f = open("C:/doit/새파일.txt", 'w')
for i in range(1, 11):
    data = "%d번째 줄입니다.\n" %i
    f.write(data)
f.close()

# %%
for i in range(1,11):
    data = "%d번째 줄입니다.\n" %i
    print(data)
# Out:
# 1번째 줄입니다.
#
# 2번째 줄입니다.
#
# 3번째 줄입니다.
#
# 4번째 줄입니다.
#
# 5번째 줄입니다.
#
# 6번째 줄입니다.
#
# 7번째 줄입니다.
#
# 8번째 줄입니다.
#
# 9번째 줄입니다.
#
# 10번째 줄입니다.

# %% [markdown]
# ######

# %% [markdown]
# #### __프로그램의 외부에 저장된 파일을 읽는 여러 가지 방법__

# %% [markdown]
# ##### readline 함수 사용하기

# %%
f = open("C:/doit/새파일.txt", "r")    # f.open("새파일.txt", 'r')로 파일을 읽기 모드로 연 후 
line = f.readline()    # readline()을 사용해서 파일의 첫 번째 줄을 읽어 출력하라.
print(line)
f.close()
# Out:
# 1번째 줄입니다.

# %%
f = open("C:/doit/새파일.txt", 'r')
while True:
    line = f.readline()
    if not line: break
    print(line)
f.close()
# Out:
# 1번째 줄입니다.
#
# 2번째 줄입니다.
#
# 3번째 줄입니다.
#
# 4번째 줄입니다.
#
# 5번째 줄입니다.
#
# 6번째 줄입니다.
#
# 7번째 줄입니다.
#
# 8번째 줄입니다.
#
# 9번째 줄입니다.
#
# 10번째 줄입니다.

# %%
while 1:
    data = input()
    if not data: break
    print(data)
# Out:
#  오
# 오

# %% [markdown]
# ##### readlines 함수 사용하기

# %%
f = open("C:/doit/새파일.txt", 'r')
lines = f.readlines()    # 파일의 모든 줄을 읽어서 각각의 줄을 요소로 갖는 리스트로 돌려준다. 
for line in lines:
    print(line)
f.close()
# Out:
# 1번째 줄입니다.
#
# 2번째 줄입니다.
#
# 3번째 줄입니다.
#
# 4번째 줄입니다.
#
# 5번째 줄입니다.
#
# 6번째 줄입니다.
#
# 7번째 줄입니다.
#
# 8번째 줄입니다.
#
# 9번째 줄입니다.
#
# 10번째 줄입니다.

# %% [markdown]
# ##### read 함수 사용하기

# %%
f = open("C:/doit/새파일.txt", 'r')
data = f.read()    # 파일의 내용 전체를 문자열로 돌려준다.
print(data)
f.close()
# Out:
# 1번째 줄입니다.
# 2번째 줄입니다.
# 3번째 줄입니다.
# 4번째 줄입니다.
# 5번째 줄입니다.
# 6번째 줄입니다.
# 7번째 줄입니다.
# 8번째 줄입니다.
# 9번째 줄입니다.
# 10번째 줄입니다.

# %% [markdown]
# #####

# %% [markdown]
# #### __파일에 새로운 내용 추가하기__

# %%
f = open("C:/doit/새파일.txt", 'a')
for i in range(11, 20):
    data = "%d 번째 줄입니다.\n" %i
    f.write(data)
f.close()

# %% [markdown]
# ####

# %% [markdown]
# #### __with문과 함께 사용하기__

# %%
f = open("foo.txt", 'w')
f.write("Life is too short, you need python")
f.close()

# %%
# 열고 닫는 것을 자동으로 처리 : with

# %%
with open("foo.txt", "w") as f:
    f.write("Life is too short, you need python")

# %%
# with 블록을 벗어나는 순간 열린 파일 객체 f가 자동으로 close 됨.

# %% [markdown]
# ######

# %%
import sys

args = sys.argv[1:]
for i in args:
    print(i)
# Out:
# -f
# C:\Users\leeal\AppData\Roaming\jupyter\runtime\kernel-efa61525-6e1d-4c95-884a-1d1d561a5eed.json

# %%
import sys
args = sys.argv[1:]
for i in args:
    print(i.upper(), end='')
# Out:
# -FC:\USERS\LEEAL\APPDATA\ROAMING\JUPYTER\RUNTIME\KERNEL-EFA61525-6E1D-4C95-884A-1D1D561A5EED.JSON

# %% [markdown]
# ######
